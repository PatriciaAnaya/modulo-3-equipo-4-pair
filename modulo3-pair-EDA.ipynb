# %% [markdown]
# # EDA

# %% [markdown]
# - Abrid el fichero de rating-and-performance con el método que sea más correcto.

# %%
import pandas as pd

# %%
df_rating = pd.read_csv('./datasets/rating-and-performance.csv', index_col=0
                        )
df_rating

# %% [markdown]
# - Mostrad las 10 últimas filas.

# %%
df_rating.tail(10)
# Out:
#                                                    title  \
# index
# 1563   ZANZEA Femmes Été Polka Dot Kaftan Beach Club ...
# 1564   2018 Femme mode d'été en dentelle Patchwork Pa...
# 1565   Nouveau Pantalon De Mode D'été Femmes Leggings...
# 1566   Robe mi-longue d'été à manches courtes pour fe...
# 1567   Combinaison sans manches pour femmes couleur u...
# 1568   Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569   10 couleurs femmes shorts d'été lacent ceintur...
# 1570   Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571   Mode femmes d'été sans manches robes col en V ...
# 1572   Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                               title_orig  price  retail_price  \
# index
# 1563   ZANZEA Women Summer Polka Dot Kaftan Beach Clu...  15.00            92
# 1564   2018 Women fashion Summer Lace Patchwork Tank ...   5.91             5
# 1565   New Summer Fashion Trousers Women Leggings Rip...   3.00             8
# 1566   Womens Short Sleeve Baggy Summer Beach Midi Dr...  11.00           134
# 1567   Sleeveless Solid Color Women Jumpsuit Ladies S...   8.00             7
# 1568   New Fashion Women Bohemia Dandelion Print Tee ...   6.00             9
# 1569   10 Color Women Summer Shorts Lace Up Elastic W...   2.00            56
# 1570   New Men Siwmwear Beach-Shorts Men Summer Quick...   5.00            19
# 1571   Fashion Women Summer Sleeveless Dresses V Neck...  13.00            11
# 1572   Fashion Women Yoga Pants Slim Fit Fitness Runn...   7.00             6
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 1563             EUR         100               0    3.51            74
# 1564             EUR        1000               0    3.38           414
# 1565             EUR         100               1    3.79            57
# 1566             EUR         100               1    3.54            28
# 1567             EUR       20000               1    4.25          3127
# 1568             EUR       10000               1    4.08          1367
# 1569             EUR         100               1    3.07            28
# 1570             EUR         100               0    3.71            59
# 1571             EUR         100               0    2.50             2
# 1572             EUR         100               1    4.07            14
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 1563                26.0  ...                 151914         4.127921
# 1564               156.0  ...                  12134         3.866903
# 1565                25.0  ...                   4080         3.987990
# 1566                 7.0  ...                   1926         4.071651
# 1567              1919.0  ...                  16803         4.155032
# 1568               722.0  ...                   5316         4.224605
# 1569                11.0  ...                   4435         3.696054
# 1570                24.0  ...                    210         3.961905
# 1571                 0.0  ...                     31         3.774194
# 1572                 8.0  ...                   7023         4.235939
#
#                     merchant_id  merchant_has_profile_picture  \
# index
# 1563   53aa664438d3046ee44a5024                             0
# 1564   58aec90823ef726994a323fe                             0
# 1565   584a7a381591451e4e3af3df                             0
# 1566   593402ae25c4f54ed4e0abdf                             0
# 1567   56455b13b15aab129db58cb7                             0
# 1568   5b507899ab577736508a0782                             0
# 1569   54d83b6b6b8a771e478558de                             0
# 1570   5b42da1bf64320209fc8da69                             0
# 1571   5d56b32c40defd78043d5af9                             0
# 1572   5a409cf87b584e7951b2e25f                             0
#
#        merchant_profile_picture  \
# index
# 1563                        NaN
# 1564                        NaN
# 1565                        NaN
# 1566                        NaN
# 1567                        NaN
# 1568                        NaN
# 1569                        NaN
# 1570                        NaN
# 1571                        NaN
# 1572                        NaN
#
#                                            product_url  \
# index
# 1563   https://www.wish.com/c/5da04c1f5949a226113006f1
# 1564   https://www.wish.com/c/5b4ed29514f0765a8a844592
# 1565   https://www.wish.com/c/5e8f0165e815903d022a3c7c
# 1566   https://www.wish.com/c/5d1060d39ed281190dfcec91
# 1567   https://www.wish.com/c/5c91a7ae7cfe8e4e64c36d97
# 1568   https://www.wish.com/c/5d5fadc99febd9356cbc52ee
# 1569   https://www.wish.com/c/5eccd22b4497b86fd48f16b4
# 1570   https://www.wish.com/c/5e74be96034d613d42b52dfe
# 1571   https://www.wish.com/c/5eda07ab0e295c2097c36590
# 1572   https://www.wish.com/c/5e857321f53c3d2d8f25e7ed
#
#                                          product_picture  \
# index
# 1563   https://contestimg.wish.com/api/webimage/5da04...
# 1564   https://contestimg.wish.com/api/webimage/5b4ed...
# 1565   https://contestimg.wish.com/api/webimage/5e8f0...
# 1566   https://contestimg.wish.com/api/webimage/5d106...
# 1567   https://contestimg.wish.com/api/webimage/5c91a...
# 1568   https://contestimg.wish.com/api/webimage/5d5fa...
# 1569   https://contestimg.wish.com/api/webimage/5eccd...
# 1570   https://contestimg.wish.com/api/webimage/5e74b...
# 1571   https://contestimg.wish.com/api/webimage/5eda0...
# 1572   https://contestimg.wish.com/api/webimage/5e857...
#
#                      product_id   theme crawl_month
# index
# 1563   5da04c1f5949a226113006f1  summer     2020-08
# 1564   5b4ed29514f0765a8a844592  summer     2020-08
# 1565   5e8f0165e815903d022a3c7c  summer     2020-08
# 1566   5d1060d39ed281190dfcec91  summer     2020-08
# 1567   5c91a7ae7cfe8e4e64c36d97  summer     2020-08
# 1568   5d5fadc99febd9356cbc52ee  summer     2020-08
# 1569   5eccd22b4497b86fd48f16b4  summer     2020-08
# 1570   5e74be96034d613d42b52dfe  summer     2020-08
# 1571   5eda07ab0e295c2097c36590  summer     2020-08
# 1572   5e857321f53c3d2d8f25e7ed  summer     2020-08
#
# [10 rows x 43 columns]

# %% [markdown]
# - Mostrad 5 filas aleatorias del DataFrame.

# %%
df_rating.sample(5)
# Out:
#                                                    title  \
# index
# 680    Chemise en coton Tops Femme Casual Casual Lâch...
# 1212   Femmes D'été Nouvelle Mode Shorts De Sport Cou...
# 658    Mode d'été Femmes Antidérapant Zipper Chaussur...
# 249    Plus la taille XS-6XL d'été femmes col rond ro...
# 46     Costume de sport cool pour hommes d'été Vêteme...
#
#                                               title_orig  price  retail_price  \
# index
# 680    Cotton Shirt Tops Women's Summer Casual Loose ...  14.00            25
# 1212   Women's Summer New Fashion Sports Shorts Solid...   3.71             4
# 658    Summer Fashion Womens Antiskid Zipper Canvas S...  14.00            12
# 249    Plus Size XS-6XL Summer Women Round Neck Sleev...  11.00            10
# 46     Summer mens cool sport suit Sports Wear Casual...  16.00            14
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 680              EUR         100               1    3.80            50
# 1212             EUR         100               1    3.44            16
# 658              EUR        1000               0    3.82           176
# 249              EUR        1000               0    4.00           221
# 46               EUR          10               0    3.00             3
#
#        rating_five_count  ...  merchant_rating_count  merchant_rating  \
# index                     ...
# 680                 23.0  ...                    230         3.908696
# 1212                 8.0  ...                  12309         4.045170
# 658                 88.0  ...                  99800         4.295792
# 249                103.0  ...                  73119         4.004267
# 46                   0.0  ...                     31         3.548387
#
#                     merchant_id  merchant_has_profile_picture  \
# index
# 680    5d46ce1a8388976d8c042c39                             0
# 1212   5acaf29d5ebcfd72403106a8                             1
# 658    58a3f270e269ee522580e6bb                             1
# 249    547465748edcfa6ceab14f70                             1
# 46     5e61c817039ce2184a0ed392                             0
#
#                                 merchant_profile_picture  \
# index
# 680                                                  NaN
# 1212   https://s3-us-west-1.amazonaws.com/sweeper-pro...
# 658    https://s3-us-west-1.amazonaws.com/sweeper-pro...
# 249    https://s3-us-west-1.amazonaws.com/sweeper-pro...
# 46                                                   NaN
#
#                                            product_url  \
# index
# 680    https://www.wish.com/c/5eaaece39229fd6f744473dc
# 1212   https://www.wish.com/c/5e9fa7c9898d87003f5891cd
# 658    https://www.wish.com/c/5cdd3515d943635651a29bbf
# 249    https://www.wish.com/c/5d550011680f557c89bb4406
# 46     https://www.wish.com/c/5e9a74e447f7d92c8db8d14b
#
#                                          product_picture  \
# index
# 680    https://contestimg.wish.com/api/webimage/5eaae...
# 1212   https://contestimg.wish.com/api/webimage/5e9fa...
# 658    https://contestimg.wish.com/api/webimage/5cdd3...
# 249    https://contestimg.wish.com/api/webimage/5d550...
# 46     https://contestimg.wish.com/api/webimage/5e9a7...
#
#                      product_id   theme crawl_month
# index
# 680    5eaaece39229fd6f744473dc  summer     2020-08
# 1212   5e9fa7c9898d87003f5891cd  summer     2020-08
# 658    5cdd3515d943635651a29bbf  summer     2020-08
# 249    5d550011680f557c89bb4406  summer     2020-08
# 46     5e9a74e447f7d92c8db8d14b  summer     2020-08
#
# [5 rows x 43 columns]

# %% [markdown]
# - ¿Cuántas filas y columnas tenemos en el DataFrame?

# %%
df_rating.shape
# Out:
# (1573, 43)

# %% [markdown]
# - ¿Cuáles son los nombres de las columnas del DataFrame?

# %%
df_rating.columns
# Out:
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %% [markdown]
# - Seleccionad solo las columnas de tipo categórico del DataFrame. Después, mostrad los valores únicos y sus frecuencias para cada una de las columnas seleccionadas.

# %%
df_rating.describe(include = "object").T
# Out:
#                           count unique  \
# title                      1573   1201
# title_orig                 1573   1203
# currency_buyer             1573      1
# tags                       1573   1230
# product_color              1532    101
# product_variation_size_id  1559    106
# shipping_option_name       1573     15
# urgency_text                473      2
# origin_country             1556      6
# merchant_title             1573    958
# merchant_name              1569    957
# merchant_info_subtitle     1572   1058
# merchant_id                1573    958
# merchant_profile_picture    226    125
# product_url                1573   1341
# product_picture            1573   1341
# product_id                 1573   1341
# theme                      1573      1
# crawl_month                1573      1
#
#                                                                          top  \
# title                      Nouvelle mode d'été femmes robe décontractée c...
# title_orig                 New Fashion Summer Women Casual Dress Round Ne...
# currency_buyer                                                           EUR
# tags                       Summer,Fashion,Necks,Skirts,Dress,Loose,Women'...
# product_color                                                          black
# product_variation_size_id                                                  S
# shipping_option_name                                      Livraison standard
# urgency_text                                              Quantité limitée !
# origin_country                                                            CN
# merchant_title                          guangzhouweishiweifushiyouxiangongsi
# merchant_name                                                    广州唯适唯服饰有限公司
# merchant_info_subtitle                     83 % avis positifs (32,168 notes)
# merchant_id                                         558c2cdc89d53c4005ea2920
# merchant_profile_picture   https://s3-us-west-1.amazonaws.com/sweeper-pro...
# product_url                  https://www.wish.com/c/5e16cb87e6dd7c03be24b28a
# product_picture            https://contestimg.wish.com/api/webimage/5e16c...
# product_id                                          5e16cb87e6dd7c03be24b28a
# theme                                                                 summer
# crawl_month                                                          2020-08
#
#                            freq
# title                        24
# title_orig                   24
# currency_buyer             1573
# tags                         17
# product_color               302
# product_variation_size_id   641
# shipping_option_name       1508
# urgency_text                472
# origin_country             1516
# merchant_title               15
# merchant_name                15
# merchant_info_subtitle       14
# merchant_id                  15
# merchant_profile_picture     12
# product_url                   3
# product_picture               3
# product_id                    3
# theme                      1573
# crawl_month                1573

# %%
df_insight.shape
# Out:
# (958, 13)

# %% [markdown]
# - En el DataFrame tenemos dos columnas que parece que nos dan la misma información "title" y "title_orig". Eliminad "title".

# %%
df_rating.columns
# Out:
# Index(['title_orig', 'price', 'retail_price', 'currency_buyer', 'units_sold',
#        'uses_ad_boosts', 'rating', 'rating_count', 'rating_five_count',
#        'rating_four_count', 'rating_three_count', 'rating_two_count',
#        'rating_one_count', 'badges_count', 'badge_local_product',
#        'badge_product_quality', 'badge_fast_shipping', 'tags', 'product_color',
#        'product_variation_size_id', 'product_variation_inventory',
#        'shipping_option_name', 'shipping_option_price', 'shipping_is_express',
#        'countries_shipped_to', 'inventory_total', 'has_urgency_banner',
#        'urgency_text', 'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %% [markdown]
# - ¿En que columnas tenemos valores nulos? Utilizad el método que más os guste.

# %%
df_rating.isnull().sum()
# Out:
# title_orig                         0
# price                              0
# retail_price                       0
# currency_buyer                     0
# units_sold                         0
# uses_ad_boosts                     0
# rating                             0
# rating_count                       0
# rating_five_count                 45
# rating_four_count                 45
# rating_three_count                45
# rating_two_count                  45
# rating_one_count                  45
# badges_count                       0
# badge_local_product                0
# badge_product_quality              0
# badge_fast_shipping                0
# tags                               0
# product_color                     41
# product_variation_size_id         14
# product_variation_inventory        0
# shipping_option_name               0
# shipping_option_price              0
# shipping_is_express                0
# countries_shipped_to               0
# inventory_total                    0
# has_urgency_banner              1100
# urgency_text                    1100
# origin_country                    17
# merchant_title                     0
# merchant_name                      4
# merchant_info_subtitle             1
# merchant_rating_count              0
# merchant_rating                    0
# merchant_id                        0
# merchant_has_profile_picture       0
# merchant_profile_picture        1347
# product_url                        0
# product_picture                    0
# product_id                         0
# theme                              0
# crawl_month                        0
# dtype: int64

# %% [markdown]
# - ¿Tenemos valores duplicados en el DataFrame?

# %%
df_rating.duplicated()
# Out:
# index
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1568    False
# 1569    False
# 1570    False
# 1571    False
# 1572    False
# Length: 1573, dtype: bool

# %%
df_rating.duplicated(['rating']).sum()
# Out:
# 1381

# %% [markdown]
# # Unión y Limpieza de Datos

# %% [markdown]
# - Unid los dos DataFrames en uno solo, usando el método que considereis más correcto. Querremos quedarnos con todos los productos que estén en los dos conjuntos de datos.

# %%
df_insight = pd.read_csv("./datasets/insight.csv", index_col = 0)

df_rating #añadido en EDA
df_insight #segundo, con el que unimos
# Out:
#                     merchant.id  listed.products  total.units.sold  \
# index
# 0      5357bcf2bb72c5504882e889                2            120000
# 1      5708773c3c02161b3f8c7900                5            107100
# 2      5417aada4ad3ab27e954b76c                2            100007
# 3      570f3a713a698c14278bb51e                1            100000
# 4      53082ea15aefb07dfe1f2a4f                1            100000
# ...                         ...              ...               ...
# 953    567bad8582c35f28103e5813                1                 2
# 954    5b24edf0d1c360301099e9c6                1                 2
# 955    5d417e7070327a2743021677                1                 1
# 956    5add589edb5f1f32114d07df                1                 1
# 957    5d4b8931933fb13f8a1fe232                1                 1
#
#        mean.units.sold.per.product  rating  merchant.ratings.count  \
# index
# 0                          60000.0   4.219                320031.0
# 1                          21420.0   3.934                139223.0
# 2                          50004.0   4.053                108048.0
# 3                         100000.0   3.889                 19248.0
# 4                         100000.0   4.036                366898.0
# ...                            ...     ...                     ...
# 953                            2.0   3.999                 21307.0
# 954                            2.0   4.303                   693.0
# 955                            1.0   3.598                   378.0
# 956                            1.0   3.956                  1134.0
# 957                            1.0   4.007                  1380.0
#
#        mean.product.prices  mean.retail.prices  average.discount  \
# index
# 0                     9.00                20.0              54.0
# 1                     7.76                34.2              61.0
# 2                     8.00                 8.0              -1.0
# 3                     5.67                19.0              71.0
# 4                     5.00                33.0              85.0
# ...                    ...                 ...               ...
# 953                  11.00                10.0             -10.0
# 954                  16.00                16.0               0.0
# 955                   2.72                 9.0              70.0
# 956                  14.00                14.0               0.0
# 957                  11.00                30.0              64.0
#
#        mean.discount  mean.product.ratings.count  total.urgency.count  \
# index
# 0               54.0                      8836.0                  1.0
# 1               61.0                      4010.0                  3.0
# 2               -1.0                      5531.0                  NaN
# 3               71.0                     18393.0                  1.0
# 4               85.0                     13789.0                  NaN
# ...              ...                         ...                  ...
# 953            -10.0                         1.0                  NaN
# 954              0.0                         0.0                  NaN
# 955             70.0                         0.0                  NaN
# 956              0.0                         0.0                  NaN
# 957             64.0                         0.0                  NaN
#
#        urgency.text.rate
# index
# 0                   50.0
# 1                   60.0
# 2                    NaN
# 3                  100.0
# 4                    NaN
# ...                  ...
# 953                  NaN
# 954                  NaN
# 955                  NaN
# 956                  NaN
# 957                  NaN
#
# [958 rows x 13 columns]

# %%
df_rating.columns
# Out:
# Index(['title_orig', 'price', 'retail_price', 'currency_buyer', 'units_sold',
#        'uses_ad_boosts', 'rating', 'rating_count', 'rating_five_count',
#        'rating_four_count', 'rating_three_count', 'rating_two_count',
#        'rating_one_count', 'badges_count', 'badge_local_product',
#        'badge_product_quality', 'badge_fast_shipping', 'tags', 'product_color',
#        'product_variation_size_id', 'product_variation_inventory',
#        'shipping_option_name', 'shipping_option_price', 'shipping_is_express',
#        'countries_shipped_to', 'inventory_total', 'has_urgency_banner',
#        'urgency_text', 'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %%
df_insight.columns
# Out:
# Index(['merchant.id', 'listed.products', 'total.units.sold',
#        'mean.units.sold.per.product', 'rating', 'merchant.ratings.count',
#        'mean.product.prices', 'mean.retail.prices', 'average.discount',
#        'mean.discount', 'mean.product.ratings.count', 'total.urgency.count',
#        'urgency.text.rate'],
#       dtype='object')

# %%
#info sobre funcion merge

df_merge.merge?

# %%
df_merge = df_rating.merge(df_insight, left_on = 'merchant_id', right_on = 'merchant.id')
df_merge.columns

# LOS ID ESTÁN DUPLICADOS, HAY QUE VER POR QUÉ Y ELIMINARNOS. MÉTODO DROPDUPLICATE
# Out:
# Index(['title_orig', 'price', 'retail_price', 'currency_buyer', 'units_sold',
#        'uses_ad_boosts', 'rating_x', 'rating_count', 'rating_five_count',
#        'rating_four_count', 'rating_three_count', 'rating_two_count',
#        'rating_one_count', 'badges_count', 'badge_local_product',
#        'badge_product_quality', 'badge_fast_shipping', 'tags', 'product_color',
#        'product_variation_size_id', 'product_variation_inventory',
#        'shipping_option_name', 'shipping_option_price', 'shipping_is_express',
#        'countries_shipped_to', 'inventory_total', 'has_urgency_banner',
#        'urgency_text', 'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month', 'merchant.id', 'listed.products',
#        'total.units.sold', 'mean.units.sold.per.product', 'rating_y',
#        'merchant.ratings.count', 'mean.product.prices', 'mean.retail.prices',
#        'average.discount', 'mean.discount', 'mean.product.ratings.count',
#        'total.urgency.count', 'urgency.text.rate'],
#       dtype='object')

# %% [markdown]
# - Explorad el nombre de las columnas, ¿hay alguna que esté repetida o que no nos aporte información de valor? ¿Hay alguna columna que solo tenga un valor? En caso de ser así, eliminadlas.
#
# NOTA Hay tres columnas que cuando exploramos sus valores únicos y sus frecuencias ayer, nos deberíamos haber dado cuenta que solo tiene un valor.

# %%
eliminar = ["crawl_month", "theme", "currency_buyer", "merchant_id"]

df_merge.drop(eliminar, axis = 1, inplace = True)
df_merge.columns
# Out:
# Index(['title_orig', 'price', 'retail_price', 'units_sold', 'uses_ad_boosts',
#        'rating_x', 'rating_count', 'rating_five_count', 'rating_four_count',
#        'rating_three_count', 'rating_two_count', 'rating_one_count',
#        'badges_count', 'badge_local_product', 'badge_product_quality',
#        'badge_fast_shipping', 'tags', 'product_color',
#        'product_variation_size_id', 'product_variation_inventory',
#        'shipping_option_name', 'shipping_option_price', 'shipping_is_express',
#        'countries_shipped_to', 'inventory_total', 'has_urgency_banner',
#        'urgency_text', 'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_has_profile_picture', 'merchant_profile_picture',
#        'product_url', 'product_picture', 'product_id', 'merchant.id',
#        'listed.products', 'total.units.sold', 'mean.units.sold.per.product',
#        'rating_y', 'merchant.ratings.count', 'mean.product.prices',
#        'mean.retail.prices', 'average.discount', 'mean.discount',
#        'mean.product.ratings.count', 'total.urgency.count',
#        'urgency.text.rate'],
#       dtype='object')

# %%
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1573 entries, 0 to 1572
# Data columns (total 55 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title_orig                    1573 non-null   object
#  1   price                         1573 non-null   float64
#  2   retail_price                  1573 non-null   int64
#  3   currency_buyer                1573 non-null   object
#  4   units_sold                    1573 non-null   int64
#  5   uses_ad_boosts                1573 non-null   int64
#  6   rating_x                      1573 non-null   float64
#  7   rating_count                  1573 non-null   int64
#  8   rating_five_count             1528 non-null   float64
#  9   rating_four_count             1528 non-null   float64
#  10  rating_three_count            1528 non-null   float64
#  11  rating_two_count              1528 non-null   float64
#  12  rating_one_count              1528 non-null   float64
#  13  badges_count                  1573 non-null   int64
#  14  badge_local_product           1573 non-null   int64
#  15  badge_product_quality         1573 non-null   int64
#  16  badge_fast_shipping           1573 non-null   int64
#  17  tags                          1573 non-null   object
#  18  product_color                 1532 non-null   object
#  19  product_variation_size_id     1559 non-null   object
#  20  product_variation_inventory   1573 non-null   int64
#  21  shipping_option_name          1573 non-null   object
#  22  shipping_option_price         1573 non-null   int64
#  23  shipping_is_express           1573 non-null   int64
#  24  countries_shipped_to          1573 non-null   int64
#  25  inventory_total               1573 non-null   int64
#  26  has_urgency_banner            473 non-null    float64
#  27  urgency_text                  473 non-null    object
#  28  origin_country                1556 non-null   object
#  29  merchant_title                1573 non-null   object
#  30  merchant_name                 1569 non-null   object
#  31  merchant_info_subtitle        1572 non-null   object
#  32  merchant_rating_count         1573 non-null   int64
#  33  merchant_rating               1573 non-null   float64
#  34  merchant_id                   1573 non-null   object
#  35  merchant_has_profile_picture  1573 non-null   int64
#  36  merchant_profile_picture      226 non-null    object
#  37  product_url                   1573 non-null   object
#  38  product_picture               1573 non-null   object
#  39  product_id                    1573 non-null   object
#  40  theme                         1573 non-null   object
#  41  crawl_month                   1573 non-null   object
#  42  merchant.id                   1573 non-null   object
#  43  listed.products               1573 non-null   int64
#  44  total.units.sold              1573 non-null   int64
#  45  mean.units.sold.per.product   1573 non-null   float64
#  46  rating_y                      1573 non-null   float64
#  47  merchant.ratings.count        1573 non-null   float64
#  48  mean.product.prices           1573 non-null   float64
#  49  mean.retail.prices            1573 non-null   float64
#  50  average.discount              1573 non-null   float64
#  51  mean.discount                 1573 non-null   float64
#  52  mean.product.ratings.count    1573 non-null   float64
#  53  total.urgency.count           905 non-null    float64
#  54  urgency.text.rate             905 non-null    float64
# dtypes: float64(19), int64(17), object(19)
# memory usage: 676.0+ KB

# %% [markdown]
# - Algunas de las columnas tienen . en sus nombres y en otras tenemos _. Unifica el nombre de las columnas para que todas tengan "_". Además, todas deben estar en minúsculas.

# %% [markdown]
# - En la columna de merchant_info_subtitle, si nos fijamos hay algunas celdas donde tenemos entre paréntesis el número total de calificaciones para el comerciante (que es la misma información que la que tenemos en la columna "merchant_rating_count"). Eliminad de la columna "merchant_info_subtitle" la parte del string de los paréntesis. Guardar el resultado de vuestra limpieza en una columna que se llame igual, es decir, "merchant_info_subtitle".

# %% [markdown]
# - Si nos fijamos, en la primera fila antes solo teníamos un paréntesis, pero los hemos eliminado en el paso anterior, y ahora tenemos un string vacío, lo cual no tiene mucho sentido. En este ejercicio debereis reemplazar esos strings vacios por nulos de Pandas (NOTA estos deben ser indicados de la siguiente forma np.nan, y deberéis importar numpy).

# %% [markdown]
# - Hay ciertas columnas que no vamos a necesitar para nuestro análisis. En concreto, vamos a eliminar las columnas de badges_count, product_variation_inventory, urgency_text, merchant_title, merchant_has_profile_picture, merchant_profile_picture, product_picture, total_urgency_count, has_urgency_banner y urgency_text_rate. Guardad los cambios realizados hasta este punto en un csv para usarlo en los ejercicios de la lección de mañana.

# %% [markdown]
# - Pongamos en práctica el filtrado de datos en Pandas:
#
#     Seleccionad aquellos productos cuyo color es verde. ¿Cuántos productos tenemos?
#
#     Seleccionad aquellos productos cuyo color es verde y rojo. ¿Cuántos productos tenemos de cada tipo de color?
#
#     Seleccionad aquellos productos de la talla M, que valgan más de 15. ¿Cuántos productos tenemos?
#
#     Seleccionad aquellos productos cuyo precio este entre 1 y 2 (ambos inclusive). ¿Cuántos productos tenemos?
#
#     Filtrad los datos, para extraer solo aquellos productos que tengan uno o más dígitos en su titulo. ¿Cuántos productos hay?
